# %%
import pandas as pd
import numpy as np

# Load the dataset
file_path = 'epu_data_final.xlsx'  # Adjust the path if the file is in a different directory
data = pd.read_excel(file_path, parse_dates=['quarter'])

# Set the 'quarter' column as the index if you want to analyze time series
data.set_index('quarter', inplace=True)

# Get descriptive statistics for the numerical variables
descriptive_stats = data.describe()

# If you want to include the variability measure beyond the standard deviation, you can compute the coefficient of variation
coeff_variation = data.std() / data.mean()

# Display the descriptive statistics
print("Descriptive Statistics:\n", descriptive_stats)

# Display the coefficient of variation for each variable
print("\nCoefficient of Variation:\n", coeff_variation)
# Out:
# Descriptive Statistics:
#               Close         Open          Low         High        Volume  \
# count   480.000000   480.000000   480.000000   480.000000  4.630000e+02
# mean    556.275642   553.411975   517.335789   589.538722  8.509597e+10
# std     773.776670   773.271401   728.530563   814.089834  2.098400e+11
# min       0.077998     0.078347     0.070922     0.087807  5.304100e+04
# 25%      25.727500    25.909412    24.345000    27.585000  1.238898e+07
# 50%     196.809773   171.917837   164.745336   204.518276  1.184637e+10
# 75%     582.326348   578.955000   539.711077   634.272500  6.765651e+10
# max    2667.390000  2609.320000  2553.190000  2755.540000  1.510692e+12
#
#                 gdp         epu  liquidity_1   liquidity_2
# count  4.800000e+02  480.000000   480.000000  4.800000e+02
# mean   1.754895e+06    0.153304     0.144807  8.208215e+10
# std    1.553112e+06    0.163360     0.101824  2.066833e+11
# min    5.351384e+04    0.000000     0.023713  0.000000e+00
# 25%    2.442468e+05    0.000000     0.080442  1.144176e+07
# 50%    1.591468e+06    0.110500     0.117732  1.040093e+10
# 75%    2.761958e+06    0.218000     0.171888  6.544715e+10
# max    7.050564e+06    0.999000     0.835078  1.510692e+12
#
# Coefficient of Variation:
#  Close          1.390995
# Open           1.397280
# Low            1.408235
# High           1.380893
# Volume         2.465922
# gdp            0.885017
# epu            1.065595
# liquidity_1    0.703168
# liquidity_2    2.518005
# dtype: float64
# C:\Users\Tam\AppData\Local\Temp/ipykernel_26096/414282170.py:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   coeff_variation = data.std() / data.mean()

# %%
descriptive_stats.to_excel('descriptive.xlsx')

# %%
coeff_variation
# Out:
# Close          1.390995
# Open           1.397280
# Low            1.408235
# High           1.380893
# Volume         2.465922
# gdp            0.885017
# epu            1.065595
# liquidity_1    0.703168
# liquidity_2    2.518005
# dtype: float64

# %%
# Compute the coefficient of correlation
correlation_matrix = data.corr()
correlation_matrix.to_excel('correlation.xlsx')

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller

# Assuming you've loaded your dataset into a DataFrame named `data`
# Example: data = pd.read_excel('epu_data_final.xlsx')

# Function to perform ADF test
def adf_test(series, name='Variable'):
    result = adfuller(series.dropna(), autolag='AIC')  # Drop NA values and select the lag automatically based on AIC
    print(f'ADF Statistic for {name}: {result[0]}')
    print(f'p-value for {name}: {result[1]}')
    print('Critical Values:')
    for key, value in result[4].items():
        print(f'   {key}: {value}')
    print("\n")

# Perform ADF test on the variables
adf_test(data['gdp'], 'GDP')
adf_test(data['epu'], 'EPU')
adf_test(data['liquidity_1'], 'Liquidity 1')
adf_test(data['liquidity_2'], 'Liquidity 2')
# Out:
# ADF Statistic for GDP: -2.1740470975864845
# p-value for GDP: 0.21579931965367355
# Critical Values:
#    1%: -3.4444914328761977
#    5%: -2.8677756786103683
#    10%: -2.570091378194011
#
#
# ADF Statistic for EPU: -7.823048552749505
# p-value for EPU: 6.5916778735610265e-12
# Critical Values:
#    1%: -3.444133731419755
#    5%: -2.8676183066831036
#    10%: -2.5700075029117166
#
#
# ADF Statistic for Liquidity 1: -5.145301650149465
# p-value for Liquidity 1: 1.1358102202001438e-05
# Critical Values:
#    1%: -3.444250937448703
#    5%: -2.867669873870454
#    10%: -2.5700349866579657
#
#
# ADF Statistic for Liquidity 2: -3.028065723161877
# p-value for Liquidity 2: 0.032355248350369036
# Critical Values:
#    1%: -3.4446148284445153
#    5%: -2.8678299626609314
#    10%: -2.5701203107928157

# %%
def perform_granger_full_output(data):
    """
    Perform Granger causality tests for specified variable pairs and print full results.
    The data parameter should be a pandas DataFrame containing the relevant series.
    """
    # List of variable pairs to test
    pairs_to_test = [('gdp', 'epu'), ('gdp', 'liquidity_1'), ('gdp', 'liquidity_2'),
                     ('epu', 'liquidity_1'), ('epu', 'liquidity_2'), ('epu', 'gdp'),
                    ('liquidity_1', 'gdp'), ('liquidity_2', 'gdp'), ('liquidity_1', 'epu'), ('liquidity_2', 'epu')]

    for x, y in pairs_to_test:
#         print(f"\nGranger Causality Test: {x} causing {y}")
        # Perform the Granger causality test
        test_result = grangercausalitytests(data[[x, y]], maxlag=5, verbose=True)

# To use this function, make sure your 'data' DataFrame is properly defined with the necessary columns,
# and then simply call the function:
# perform_granger_full_output(data)

# %%
perform_granger_full_output(data)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0003  , p=0.9856  , df_denom=476, df_num=1
# ssr based chi2 test:   chi2=0.0003  , p=0.9855  , df=1
# likelihood ratio test: chi2=0.0003  , p=0.9855  , df=1
# parameter F test:         F=0.0003  , p=0.9856  , df_denom=476, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0991  , p=0.9056  , df_denom=473, df_num=2
# ssr based chi2 test:   chi2=0.2004  , p=0.9047  , df=2
# likelihood ratio test: chi2=0.2003  , p=0.9047  , df=2
# parameter F test:         F=0.0991  , p=0.9056  , df_denom=473, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0472  , p=0.9864  , df_denom=470, df_num=3
# ssr based chi2 test:   chi2=0.1437  , p=0.9861  , df=3
# likelihood ratio test: chi2=0.1437  , p=0.9861  , df=3
# parameter F test:         F=0.0472  , p=0.9864  , df_denom=470, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1203  , p=0.9752  , df_denom=467, df_num=4
# ssr based chi2 test:   chi2=0.4906  , p=0.9744  , df=4
# likelihood ratio test: chi2=0.4903  , p=0.9744  , df=4
# parameter F test:         F=0.1203  , p=0.9752  , df_denom=467, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.3205  , p=0.9006  , df_denom=464, df_num=5
# ssr based chi2 test:   chi2=1.6407  , p=0.8963  , df=5
# likelihood ratio test: chi2=1.6379  , p=0.8966  , df=5
# parameter F test:         F=0.3205  , p=0.9006  , df_denom=464, df_num=5
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.7381  , p=0.0300  , df_denom=476, df_num=1
# ssr based chi2 test:   chi2=4.7680  , p=0.0290  , df=1
# likelihood ratio test: chi2=4.7444  , p=0.0294  , df=1
# parameter F test:         F=4.7381  , p=0.0300  , df_denom=476, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.6678  , p=0.0704  , df_denom=473, df_num=2
# ssr based chi2 test:   chi2=5.3920  , p=0.0675  , df=2
# likelihood ratio test: chi2=5.3618  , p=0.0685  , df=2
# parameter F test:         F=2.6678  , p=0.0704  , df_denom=473, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6920  , p=0.1679  , df_denom=470, df_num=3
# ssr based chi2 test:   chi2=5.1516  , p=0.1610  , df=3
# likelihood ratio test: chi2=5.1240  , p=0.1629  , df=3
# parameter F test:         F=1.6920  , p=0.1679  , df_denom=470, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7665  , p=0.5474  , df_denom=467, df_num=4
# ssr based chi2 test:   chi2=3.1252  , p=0.5371  , df=4
# likelihood ratio test: chi2=3.1150  , p=0.5388  , df=4
# parameter F test:         F=0.7665  , p=0.5474  , df_denom=467, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.4579  , p=0.0325  , df_denom=464, df_num=5
# ssr based chi2 test:   chi2=12.5809 , p=0.0276  , df=5
# likelihood ratio test: chi2=12.4171 , p=0.0295  , df=5
# parameter F test:         F=2.4579  , p=0.0325  , df_denom=464, df_num=5
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9897  , p=0.3203  , df_denom=476, df_num=1
# ssr based chi2 test:   chi2=0.9960  , p=0.3183  , df=1
# likelihood ratio test: chi2=0.9949  , p=0.3185  , df=1
# parameter F test:         F=0.9897  , p=0.3203  , df_denom=476, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8383  , p=0.4331  , df_denom=473, df_num=2
# ssr based chi2 test:   chi2=1.6944  , p=0.4286  , df=2
# likelihood ratio test: chi2=1.6914  , p=0.4293  , df=2
# parameter F test:         F=0.8383  , p=0.4331  , df_denom=473, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8451  , p=0.4697  , df_denom=470, df_num=3
# ssr based chi2 test:   chi2=2.5730  , p=0.4622  , df=3
# likelihood ratio test: chi2=2.5661  , p=0.4635  , df=3
# parameter F test:         F=0.8451  , p=0.4697  , df_denom=470, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.1638  , p=0.0721  , df_denom=467, df_num=4
# ssr based chi2 test:   chi2=8.8221  , p=0.0657  , df=4
# likelihood ratio test: chi2=8.7414  , p=0.0679  , df=4
# parameter F test:         F=2.1638  , p=0.0721  , df_denom=467, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1642  , p=0.3258  , df_denom=464, df_num=5
# ssr based chi2 test:   chi2=5.9588  , p=0.3102  , df=5
# likelihood ratio test: chi2=5.9217  , p=0.3139  , df=5
# parameter F test:         F=1.1642  , p=0.3258  , df_denom=464, df_num=5
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4555  , p=0.2282  , df_denom=476, df_num=1
# ssr based chi2 test:   chi2=1.4647  , p=0.2262  , df=1
# likelihood ratio test: chi2=1.4624  , p=0.2265  , df=1
# parameter F test:         F=1.4555  , p=0.2282  , df_denom=476, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3401  , p=0.2628  , df_denom=473, df_num=2
# ssr based chi2 test:   chi2=2.7085  , p=0.2581  , df=2
# likelihood ratio test: chi2=2.7008  , p=0.2591  , df=2
# parameter F test:         F=1.3401  , p=0.2628  , df_denom=473, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4211  , p=0.2359  , df_denom=470, df_num=3
# ssr based chi2 test:   chi2=4.3267  , p=0.2283  , df=3
# likelihood ratio test: chi2=4.3072  , p=0.2301  , df=3
# parameter F test:         F=1.4211  , p=0.2359  , df_denom=470, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0700  , p=0.3707  , df_denom=467, df_num=4
# ssr based chi2 test:   chi2=4.3625  , p=0.3592  , df=4
# likelihood ratio test: chi2=4.3426  , p=0.3616  , df=4
# parameter F test:         F=1.0700  , p=0.3707  , df_denom=467, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2073  , p=0.3046  , df_denom=464, df_num=5
# ssr based chi2 test:   chi2=6.1794  , p=0.2892  , df=5
# likelihood ratio test: chi2=6.1395  , p=0.2929  , df=5
# parameter F test:         F=1.2073  , p=0.3046  , df_denom=464, df_num=5
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0134  , p=0.9080  , df_denom=476, df_num=1
# ssr based chi2 test:   chi2=0.0135  , p=0.9076  , df=1
# likelihood ratio test: chi2=0.0135  , p=0.9076  , df=1
# parameter F test:         F=0.0134  , p=0.9080  , df_denom=476, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2200  , p=0.8026  , df_denom=473, df_num=2
# ssr based chi2 test:   chi2=0.4447  , p=0.8006  , df=2
# likelihood ratio test: chi2=0.4445  , p=0.8007  , df=2
# parameter F test:         F=0.2199  , p=0.8027  , df_denom=473, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3095  , p=0.8185  , df_denom=470, df_num=3
# ssr based chi2 test:   chi2=0.9424  , p=0.8152  , df=3
# likelihood ratio test: chi2=0.9415  , p=0.8154  , df=3
# parameter F test:         F=0.3098  , p=0.8183  , df_denom=470, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3711  , p=0.8293  , df_denom=467, df_num=4
# ssr based chi2 test:   chi2=1.5129  , p=0.8244  , df=4
# likelihood ratio test: chi2=1.5105  , p=0.8248  , df=4
# parameter F test:         F=0.3714  , p=0.8290  , df_denom=467, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.3040  , p=0.9105  , df_denom=464, df_num=5
# ssr based chi2 test:   chi2=1.5559  , p=0.9065  , df=5
# likelihood ratio test: chi2=1.5533  , p=0.9068  , df=5
# parameter F test:         F=0.3036  , p=0.9107  , df_denom=464, df_num=5
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8758  , p=0.3498  , df_denom=476, df_num=1
# ssr based chi2 test:   chi2=0.8813  , p=0.3478  , df=1
# likelihood ratio test: chi2=0.8805  , p=0.3481  , df=1
# parameter F test:         F=0.8758  , p=0.3498  , df_denom=476, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3408  , p=0.7114  , df_denom=473, df_num=2
# ssr based chi2 test:   chi2=0.6889  , p=0.7086  , df=2
# likelihood ratio test: chi2=0.6884  , p=0.7088  , df=2
# parameter F test:         F=0.3408  , p=0.7114  , df_denom=473, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4118  , p=0.7446  , df_denom=470, df_num=3
# ssr based chi2 test:   chi2=1.2537  , p=0.7402  , df=3
# likelihood ratio test: chi2=1.2520  , p=0.7406  , df=3
# parameter F test:         F=0.4118  , p=0.7446  , df_denom=470, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4799  , p=0.7505  , df_denom=467, df_num=4
# ssr based chi2 test:   chi2=1.9567  , p=0.7437  , df=4
# likelihood ratio test: chi2=1.9527  , p=0.7445  , df=4
# parameter F test:         F=0.4799  , p=0.7505  , df_denom=467, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5315  , p=0.7525  , df_denom=464, df_num=5
# ssr based chi2 test:   chi2=2.7204  , p=0.7430  , df=5
# likelihood ratio test: chi2=2.7126  , p=0.7442  , df=5
# parameter F test:         F=0.5315  , p=0.7525  , df_denom=464, df_num=5
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0299  , p=0.8627  , df_denom=476, df_num=1
# ssr based chi2 test:   chi2=0.0301  , p=0.8622  , df=1
# likelihood ratio test: chi2=0.0301  , p=0.8622  , df=1
# parameter F test:         F=0.0299  , p=0.8627  , df_denom=476, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.2310  , p=0.1086  , df_denom=473, df_num=2
# ssr based chi2 test:   chi2=4.5091  , p=0.1049  , df=2
# likelihood ratio test: chi2=4.4880  , p=0.1060  , df=2
# parameter F test:         F=2.2310  , p=0.1086  , df_denom=473, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.1722  , p=0.0905  , df_denom=470, df_num=3
# ssr based chi2 test:   chi2=6.6135  , p=0.0853  , df=3
# likelihood ratio test: chi2=6.5681  , p=0.0870  , df=3
# parameter F test:         F=2.1722  , p=0.0905  , df_denom=470, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.7753  , p=0.1326  , df_denom=467, df_num=4
# ssr based chi2 test:   chi2=7.2382  , p=0.1238  , df=4
# likelihood ratio test: chi2=7.1837  , p=0.1265  , df=4
# parameter F test:         F=1.7753  , p=0.1326  , df_denom=467, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1333  , p=0.3418  , df_denom=464, df_num=5
# ssr based chi2 test:   chi2=5.8007  , p=0.3261  , df=5
# likelihood ratio test: chi2=5.7656  , p=0.3297  , df=5
# parameter F test:         F=1.1333  , p=0.3418  , df_denom=464, df_num=5
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0252  , p=0.8740  , df_denom=476, df_num=1
# ssr based chi2 test:   chi2=0.0253  , p=0.8735  , df=1
# likelihood ratio test: chi2=0.0253  , p=0.8735  , df=1
# parameter F test:         F=0.0252  , p=0.8740  , df_denom=476, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0360  , p=0.9646  , df_denom=473, df_num=2
# ssr based chi2 test:   chi2=0.0728  , p=0.9642  , df=2
# likelihood ratio test: chi2=0.0728  , p=0.9642  , df=2
# parameter F test:         F=0.0360  , p=0.9646  , df_denom=473, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0623  , p=0.9796  , df_denom=470, df_num=3
# ssr based chi2 test:   chi2=0.1897  , p=0.9792  , df=3
# likelihood ratio test: chi2=0.1897  , p=0.9792  , df=3
# parameter F test:         F=0.0623  , p=0.9796  , df_denom=470, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2115  , p=0.9321  , df_denom=467, df_num=4
# ssr based chi2 test:   chi2=0.8621  , p=0.9299  , df=4
# likelihood ratio test: chi2=0.8613  , p=0.9300  , df=4
# parameter F test:         F=0.2115  , p=0.9321  , df_denom=467, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2852  , p=0.9212  , df_denom=464, df_num=5
# ssr based chi2 test:   chi2=1.4598  , p=0.9177  , df=5
# likelihood ratio test: chi2=1.4575  , p=0.9179  , df=5
# parameter F test:         F=0.2852  , p=0.9212  , df_denom=464, df_num=5
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.5211  , p=0.0110  , df_denom=476, df_num=1
# ssr based chi2 test:   chi2=6.5622  , p=0.0104  , df=1
# likelihood ratio test: chi2=6.5176  , p=0.0107  , df=1
# parameter F test:         F=6.5211  , p=0.0110  , df_denom=476, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.2638  , p=0.0391  , df_denom=473, df_num=2
# ssr based chi2 test:   chi2=6.5966  , p=0.0369  , df=2
# likelihood ratio test: chi2=6.5515  , p=0.0378  , df=2
# parameter F test:         F=3.2638  , p=0.0391  , df_denom=473, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.3175  , p=0.0051  , df_denom=470, df_num=3
# ssr based chi2 test:   chi2=13.1453 , p=0.0043  , df=3
# likelihood ratio test: chi2=12.9674 , p=0.0047  , df=3
# parameter F test:         F=4.3175  , p=0.0051  , df_denom=470, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.4582  , p=0.0085  , df_denom=467, df_num=4
# ssr based chi2 test:   chi2=14.0993 , p=0.0070  , df=4
# likelihood ratio test: chi2=13.8945 , p=0.0076  , df=4
# parameter F test:         F=3.4582  , p=0.0085  , df_denom=467, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.5247  , p=0.0286  , df_denom=464, df_num=5
# ssr based chi2 test:   chi2=12.9228 , p=0.0241  , df=5
# likelihood ratio test: chi2=12.7502 , p=0.0258  , df=5
# parameter F test:         F=2.5247  , p=0.0286  , df_denom=464, df_num=5
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0559  , p=0.8133  , df_denom=476, df_num=1
# ssr based chi2 test:   chi2=0.0562  , p=0.8126  , df=1
# likelihood ratio test: chi2=0.0562  , p=0.8126  , df=1
# parameter F test:         F=0.0559  , p=0.8133  , df_denom=476, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0263  , p=0.9740  , df_denom=473, df_num=2
# ssr based chi2 test:   chi2=0.0532  , p=0.9738  , df=2
# likelihood ratio test: chi2=0.0532  , p=0.9738  , df=2
# parameter F test:         F=0.0263  , p=0.9740  , df_denom=473, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1364  , p=0.9383  , df_denom=470, df_num=3
# ssr based chi2 test:   chi2=0.4154  , p=0.9371  , df=3
# likelihood ratio test: chi2=0.4152  , p=0.9371  , df=3
# parameter F test:         F=0.1364  , p=0.9383  , df_denom=470, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1859  , p=0.9457  , df_denom=467, df_num=4
# ssr based chi2 test:   chi2=0.7579  , p=0.9440  , df=4
# likelihood ratio test: chi2=0.7573  , p=0.9441  , df=4
# parameter F test:         F=0.1859  , p=0.9457  , df_denom=467, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4615  , p=0.8049  , df_denom=464, df_num=5
# ssr based chi2 test:   chi2=2.3620  , p=0.7971  , df=5
# likelihood ratio test: chi2=2.3561  , p=0.7980  , df=5
# parameter F test:         F=0.4615  , p=0.8049  , df_denom=464, df_num=5

# %%
import pandas as pd
from statsmodels.tsa.stattools import grangercausalitytests

def perform_granger_full_output_and_tabulate(data):
    """
    Perform Granger causality tests for specified variable pairs, print full results,
    and tabulate the key statistics in a DataFrame, rounding results to three decimal places.
    """
    data['gdp_diff'] = data['gdp'].diff()  # Calculate the first difference of 'gdp'

    pairs_to_test = [('gdp_diff', 'epu'), ('gdp_diff', 'liquidity_1'), ('gdp_diff', 'liquidity_2'),
                     ('epu', 'liquidity_1'), ('epu', 'liquidity_2'), ('epu', 'gdp_diff'),
                     ('liquidity_1', 'gdp_diff'), ('liquidity_2', 'gdp_diff'), ('liquidity_1', 'epu'), ('liquidity_2', 'epu')]

    # Prepare an empty list to store results
    results = []

    for x, y in pairs_to_test:
        test_result = grangercausalitytests(data[[x, y]].dropna(), maxlag=5, verbose=False)
        
        # Extract required statistics for each lag and round them to three decimal places
        for lag, stats in test_result.items():
            chi2value = round(stats[0]['ssr_chi2test'][0], 3)
            p_value_chi2 = round(stats[0]['ssr_chi2test'][1], 3)
            f_value = round(stats[0]['params_ftest'][0], 3)
            p_value_f = round(stats[0]['params_ftest'][1], 3)
            results.append([f"{x} causing {y}", lag, chi2value, p_value_chi2, f_value, p_value_f])
    
    # Convert results into a DataFrame
    results_df = pd.DataFrame(results, columns=['Test', 'Lag', 'Chi2 Value', 'P-Value of Chi2', 'F Value', 'P-Value of F-test'])
    return results_df

# Example usage
# Assuming 'data' is your DataFrame with the necessary columns:
# results_df = perform_granger_full_output_and_tabulate(data)
# print(results_df)

# %%
perform_granger_full_output_and_tabulate(data)
# Out:
#                             Test  Lag  Chi2 Value  P-Value of Chi2  F Value  \
# 0           gdp_diff causing epu    1       0.138            0.710    0.137
# 1           gdp_diff causing epu    2       0.176            0.916    0.087
# 2           gdp_diff causing epu    3       0.217            0.975    0.071
# 3           gdp_diff causing epu    4       0.966            0.915    0.237
# 4           gdp_diff causing epu    5       1.264            0.939    0.247
# 5   gdp_diff causing liquidity_1    1       4.800            0.028    4.770
# 6   gdp_diff causing liquidity_1    2       3.855            0.146    1.907
# 7   gdp_diff causing liquidity_1    3       2.294            0.514    0.753
# 8   gdp_diff causing liquidity_1    4       9.778            0.044    2.398
# 9   gdp_diff causing liquidity_1    5      11.540            0.042    2.254
# 10  gdp_diff causing liquidity_2    1       0.041            0.839    0.041
# 11  gdp_diff causing liquidity_2    2       1.674            0.433    0.828
# 12  gdp_diff causing liquidity_2    3       5.003            0.172    1.643
# 13  gdp_diff causing liquidity_2    4       3.272            0.513    0.803
# 14  gdp_diff causing liquidity_2    5       5.769            0.329    1.127
# 15       epu causing liquidity_1    1       1.465            0.226    1.455
# 16       epu causing liquidity_1    2       2.708            0.258    1.340
# 17       epu causing liquidity_1    3       4.327            0.228    1.421
# 18       epu causing liquidity_1    4       4.362            0.359    1.070
# 19       epu causing liquidity_1    5       6.179            0.289    1.207
# 20       epu causing liquidity_2    1       0.013            0.908    0.013
# 21       epu causing liquidity_2    2       0.445            0.801    0.220
# 22       epu causing liquidity_2    3       0.942            0.815    0.310
# 23       epu causing liquidity_2    4       1.513            0.824    0.371
# 24       epu causing liquidity_2    5       1.556            0.907    0.304
# 25          epu causing gdp_diff    1       0.103            0.748    0.103
# 26          epu causing gdp_diff    2       0.676            0.713    0.335
# 27          epu causing gdp_diff    3       1.151            0.765    0.378
# 28          epu causing gdp_diff    4       2.030            0.730    0.498
# 29          epu causing gdp_diff    5       4.961            0.421    0.969
# 30  liquidity_1 causing gdp_diff    1       2.559            0.110    2.543
# 31  liquidity_1 causing gdp_diff    2       5.879            0.053    2.909
# 32  liquidity_1 causing gdp_diff    3       6.732            0.081    2.211
# 33  liquidity_1 causing gdp_diff    4       6.132            0.190    1.504
# 34  liquidity_1 causing gdp_diff    5       6.008            0.305    1.174
# 35  liquidity_2 causing gdp_diff    1       0.014            0.907    0.014
# 36  liquidity_2 causing gdp_diff    2       0.078            0.962    0.039
# 37  liquidity_2 causing gdp_diff    3       0.241            0.971    0.079
# 38  liquidity_2 causing gdp_diff    4       2.083            0.721    0.511
# 39  liquidity_2 causing gdp_diff    5       4.762            0.446    0.930
# 40       liquidity_1 causing epu    1       6.562            0.010    6.521
# 41       liquidity_1 causing epu    2       6.597            0.037    3.264
# 42       liquidity_1 causing epu    3      13.145            0.004    4.317
# 43       liquidity_1 causing epu    4      14.099            0.007    3.458
# 44       liquidity_1 causing epu    5      12.923            0.024    2.525
# 45       liquidity_2 causing epu    1       0.056            0.813    0.056
# 46       liquidity_2 causing epu    2       0.053            0.974    0.026
# 47       liquidity_2 causing epu    3       0.415            0.937    0.136
# 48       liquidity_2 causing epu    4       0.758            0.944    0.186
# 49       liquidity_2 causing epu    5       2.362            0.797    0.461
#
#     P-Value of F-test
# 0               0.712
# 1               0.917
# 2               0.975
# 3               0.917
# 4               0.941
# 5               0.029
# 6               0.150
# 7               0.521
# 8               0.049
# 9               0.048
# 10              0.840
# 11              0.437
# 12              0.179
# 13              0.524
# 14              0.345
# 15              0.228
# 16              0.263
# 17              0.236
# 18              0.371
# 19              0.305
# 20              0.908
# 21              0.803
# 22              0.818
# 23              0.829
# 24              0.911
# 25              0.749
# 26              0.716
# 27              0.769
# 28              0.737
# 29              0.436
# 30              0.111
# 31              0.056
# 32              0.086
# 33              0.200
# 34              0.321
# 35              0.907
# 36              0.962
# 37              0.971
# 38              0.728
# 39              0.461
# 40              0.011
# 41              0.039
# 42              0.005
# 43              0.008
# 44              0.029
# 45              0.813
# 46              0.974
# 47              0.938
# 48              0.946
# 49              0.805

# %%
perform_granger_full_output_and_tabulate(data).to_excel('granger_result.xlsx')
